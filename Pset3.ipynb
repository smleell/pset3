# %% [markdown]
# # Problem set 3
# ## Seongmin Lee

# %%
# Problem 1

fhand = open('/blue/bsc4452/share/Class_Files/data/CO-OPS_8727520_wl.csv')
next(fhand) # Skip first line

# Set the values
max_level = None 
max_date = None
max_time = None
for line in fhand:
    lis = line.split(',') # Convert each line to list
    date = lis[0].strip('"') # Remove quotations
    time = lis[1].strip('"')
    preliminary = lis[3].strip('"')
    level = float(preliminary) # Convert string to float
    if max_level is None or level > max_level:
            max_level = level
            max_date = date
            max_time = time
print(f'The highest water level is {max_level} ft on {max_date} at {max_time}.')
# Out:
# The highest water level is 13.1 ft on 2024/09/27 at 04:42.

# %%
# Problem 2

# Find lowest
fhand = open('/blue/bsc4452/share/Class_Files/data/CO-OPS_8727520_wl.csv')
next(fhand)
min_level = None 
min_date = None
min_time = None
for line in fhand:
    lis = line.split(',')
    date = lis[0].strip('"')
    time = lis[1].strip('"')
    preliminary = lis[3].strip('"')
    level = float(preliminary)
    if min_level is None or level < min_level:
            min_level = level
            min_date = date
            min_time = time
print(f'The lowest water level is {min_level} ft on {min_date} at {min_time}.')

# Find highest
fhand.seek(0)
next(fhand)
max_level = None 
max_date = None
max_time = None
for line in fhand:
    lis = line.split(',') 
    date = lis[0].strip('"')
    time = lis[1].strip('"')
    preliminary = lis[3].strip('"')
    level = float(preliminary)
    if max_level is None or level > max_level:
            max_level = level
            max_date = date
            max_time = time
print(f'The highest water level is {max_level} ft on {max_date} at {max_time}.')

# Find average
fhand.seek(0)
next(fhand)
count = 0
total = 0
for line in fhand:
    lis = line.split(',')
    preliminary = lis[3].strip('"')
    level = float(preliminary)
    count += 1
    total = total + level
    avg_level = total / count
print(f'The average water level is {avg_level:.2f} ft.')
# Out:
# The lowest water level is 1.53 ft on 2024/09/27 at 23:00.
# The highest water level is 13.1 ft on 2024/09/27 at 04:42.
# The average water level is 5.68 ft.

# %%
# Problem 3

fhand = open('/blue/bsc4452/share/Class_Files/data/CO-OPS_8727520_wl.csv')
next(fhand)
previous_level = None
max_gap = 0
date1 = None
date2 = None
time1 = None
time2 = None
for line in fhand:
    lis = line.split(',')
    date = lis[0].strip('"')
    time = lis[1].strip('"')
    preliminary = lis[3].strip('"')
    current_level = float(preliminary)
    if previous_level != None: 
    # if previous_level=None, skip and automatically previous = current
        gap = abs(current_level - previous_level)
        if max_gap < gap:
            max_gap = gap # Update values
            date1 = previous_date
            date2 = date
            time1 = previous_time
            time2 = time
           # see the results
           # print(date1, date2, time1, time2, previous_level, current_level, max_gap)
    previous_level = current_level
    previous_date = date
    previous_time = time # iteration
print(f'The fastest rise in water level is between {date1} at {time1} and {date2} at {time2}, and the change in water value is {round(max_gap, 2)} ft.')
# Out:
# The fastest rise in water level is between 2024/09/27 at 01:06 and 2024/09/27 at 01:12, and the change in water value is 0.61 ft.

# %%
# Problem 4

fhand = open('/blue/bsc4452/share/Class_Files/data/CO-OPS_8727520_wl.csv')
next(fhand)
previous_level = None
for line in fhand:
    lis = line.split(',')
    date = lis[0].strip('"')
    time = lis[1].strip('"')
    preliminary = lis[3].strip('"')
    if preliminary == '-':
        print(f'🚨WARNING!🚨: No reading received on {date} at {time}.')
    else: 
        current_level = float(preliminary)
        if previous_level != None:
            gap = current_level - previous_level
            if gap > 0.25:
                print(f'🚨WARNING!🚨: Water level increased by more than 0.25 ft on {date} at {time}.')
        previous_level = current_level
        if current_level > 5.0:
            print(f'🚨WARNING!🚨: Water level is over 5.0 ft on {date} at {time}.')
# Out:
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/26 at 01:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 10:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 10:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 10:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 11:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 11:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 11:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 11:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 11:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 11:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 11:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 12:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 13:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:42.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/26 at 14:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 14:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 15:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 16:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 17:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 18:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 18:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 18:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 18:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 18:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 18:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 18:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 19:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 19:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 21:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 21:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 21:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 22:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:42.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/26 at 23:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:48.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/26 at 23:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/26 at 23:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 00:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:06.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/27 at 01:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:12.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/27 at 01:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:48.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/27 at 01:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 01:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:06.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/27 at 02:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:24.
# 🚨WARNING!🚨: Water level increased by more than 0.25 ft on 2024/09/27 at 02:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 02:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 03:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 04:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 05:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 06:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 07:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 08:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 09:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 10:54.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:00.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:06.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:12.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:18.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:24.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:30.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:36.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:42.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:48.
# 🚨WARNING!🚨: Water level is over 5.0 ft on 2024/09/27 at 11:54.
